# %%
from __future__ import print_function
from tensorflow.keras import backend as K
from tensorflow.keras import layers, Sequential, regularizers
from tensorflow.keras.layers import Layer
from tensorflow.keras import activations
from tensorflow.keras import utils
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
#from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler

#import keras
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers

from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import math
from itertools import cycle
import numpy as np
import pandas as pd
#import seaborn as sn
from matplotlib import pyplot as plt

from utils import *
from layers import *

K.set_image_data_format('channels_last')

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  #按需分配显存
session = tf.compat.v1.Session(config=config)

tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
def capsnet(inputs):
    x = Conv2D(16, 5, 1, padding='same', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization(axis=3, center=True, scale=True, beta_initializer="random_uniform", gamma_initializer="random_uniform")(x)
    x = ReLU()(x)
    
    x = MaxPooling2D()(x)
    
    x = Conv2D(32, 5, 1, padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3, center=True, scale=True, beta_initializer="random_uniform", gamma_initializer="random_uniform")(x)
    x = LeakyReLU()(x)
    
    x = MaxPooling2D()(x)
    
    x = Conv2D(64, 5, 1, padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3, center=True, scale=True, beta_initializer="random_uniform", gamma_initializer="random_uniform")(x)
    x = LeakyReLU()(x)
    
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, 5, 1, padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization(axis=3, center=True, scale=True, beta_initializer="random_uniform", gamma_initializer="random_uniform")(x)
    x = LeakyReLU()(x)

    
    x = PrimaryCaps_H(32, 8, 9, 1, padding='SAME')(x)

    digit_caps = DigitCaps(3, 16, 3)(x)


    digit_caps_len = Lambda(lambda z: K.sqrt(K.sum(K.square(z), 2)))(digit_caps)
    model = Model(inputs=[inputs], outputs=[digit_caps, digit_caps_len], name='CapsNet')

    return model

# %%
def generator(input_shape):
    inputs = Input(16*3)
    
    x = tf.keras.layers.Dense(512, activation='relu')(inputs)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dense(np.prod(input_shape), activation='sigmoid')(x)
    x = tf.keras.layers.Reshape(target_shape=input_shape, name='out_generator')(x)
    
    return Model(inputs=[inputs], outputs=[x], name='Generator')

# %%
class Mask(Layer):
    def call(self, inputs, double_mask=None, **kwargs):
        if type(inputs) is list:
            if double_mask:
                inputs, mask1, mask2 = inputs
            else:
                inputs, mask = inputs
        else:  
            x = tf.sqrt(tf.reduce_sum(tf.square(inputs), -1))
            if double_mask:
                mask1 = tf.keras.backend.one_hot(tf.argsort(x,direction='DESCENDING',axis=-1)[...,0],num_classes=x.get_shape().as_list()[1])
                mask2 = tf.keras.backend.one_hot(tf.argsort(x,direction='DESCENDING',axis=-1)[...,1],num_classes=x.get_shape().as_list()[1])
            else:
                mask = tf.keras.backend.one_hot(indices=tf.argmax(x, 1), num_classes=x.get_shape().as_list()[1])

        if double_mask:
            masked1 = tf.keras.backend.batch_flatten(inputs * tf.expand_dims(mask1, -1))
            masked2 = tf.keras.backend.batch_flatten(inputs * tf.expand_dims(mask2, -1))
            return masked1, masked2
        else:
            masked = tf.keras.backend.batch_flatten(inputs * tf.expand_dims(mask, -1))
            return masked

    def compute_output_shape(self, input_shape):
        if type(input_shape[0]) is tuple:  
            return tuple([None, input_shape[0][1] * input_shape[0][2]])
        else:  # generation step
            return tuple([None, input_shape[1] * input_shape[2]])

    def get_config(self):
        config = super(Mask, self).get_config()
        return config

# %%
def create_model(inputs, y_true, mode='train'):
    capsnet_model = capsnet(inputs)
    digit_caps, digit_caps_len = capsnet_model(inputs)
    
    # 重构
    masked_by_y = Mask()([digit_caps, y_true])  
    masked = Mask()(digit_caps)
    
    generator_model = generator([128, 128, 3])
    x_gen_train = generator_model(masked_by_y)
    x_gen_eval = generator_model(masked)
    
    if mode == 'train':   
        return Model([inputs, y_true], [digit_caps_len, x_gen_train], name='CapsNet_Generator')
    elif mode == 'test':
        return Model(inputs, [digit_caps_len, x_gen_eval], name='CapsNet_Generator')
    else:
        raise RuntimeError('mode not recognized')

# %%
inputs = Input(shape=(128, 128, 3))
y_true = Input(shape=(3,))

model = create_model(inputs, y_true)

# %%
adam = optimizers.Adam(lr=0.0001) 

model.compile(loss=[margin_loss, 'mse'], optimizer=adam, loss_weights=[1., 0.392], metrics={'CapsNet': 'accuracy'})
model.summary()
# Out:
# Model: "CapsNet_Generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# CapsNet (Functional)            [(None, 3, 16), (Non 6071440     input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# mask (Mask)                     (None, 48)           0           CapsNet[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# Generator (Functional)          (None, 128, 128, 3)  50931200    mask[0][0]
# ==================================================================================================
# Total params: 57,002,640
# Trainable params: 57,002,160
# Non-trainable params: 480
# __________________________________________________________________________________________________

# %%
#learning decay rate schedule
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.5 
    epochs_drop = 20  
    lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop))
    return lrate

# %%
batch_size = 16  
num_classes = 3
epochs = 100

images= np.load("data/image.npy")
labels= np.load("data/label.npy")

# %%
def generator_(image, label):
    return (image, label), (label, image)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# define 5-fold cross validation test harness
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=3)
cvscores = []
cvpre = []
cvrecall  =[]
cvf1 = []
cvauc = []

for k, (train, test) in enumerate(kfold.split(images, labels)):
    
    path = "model/"
    
    x_train = images[train]
    x_test = images[test]
    y_train = labels[train]
    y_test = labels[test]
    
#     np.save(path + 'data/x_train.npy', x_train)
#     np.save(path + 'data/y_train.npy', y_train)
#     np.save(path + 'data/x_test.npy', x_test)
#     np.save(path + 'data/y_test.npy', y_test)
    
    #class weights to handle class imbalance
    class_weights = {0: 1-np.count_nonzero(y_train==0)/len(y_train), 
                     1: 1-np.count_nonzero(y_train==1)/len(y_train), 
                     2: 1-np.count_nonzero(y_train==2)/len(y_train)}

    # 将整型标签转为onehot
    y_train = utils.to_categorical(y_train, num_classes)
    y_test = utils.to_categorical(y_test, num_classes)
    
    dataset_train = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    dataset_train = dataset_train.map(generator_, num_parallel_calls=16)
    dataset_train = dataset_train.batch(batch_size)
    dataset_train = dataset_train.prefetch(-1)

    dataset_test = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    dataset_test = dataset_test.map(generator_, num_parallel_calls=16)
    dataset_test = dataset_test.batch(batch_size)
    dataset_test = dataset_test.prefetch(-1)
    
    
    # The best model is selected based on the loss value on the validation set
    filepath = path+"cg-weights-best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_CapsNet_accuracy',
                                 save_best_only=True, save_weights_only=True, verbose=1, mode='max')

    
    # learning schedule callback
    lrate = LearningRateScheduler(step_decay)

    callbacks_list = [checkpoint, lrate]
    

    #===================================Model======================================
    inputs = Input(shape=(128, 128, 3))
    y_true = Input(shape=(3,))
    model = create_model(inputs, y_true)
    adam = optimizers.Adam(lr=0.0001) 
    model.compile(loss=[margin_loss, 'mse'], optimizer=adam, loss_weights=[1., 0.392], metrics={'CapsNet': 'accuracy'})
    
    print("========================= 第"+ str(k+1) +"折开始 ============================")
    history = model.fit(dataset_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    validation_data=(dataset_test), 
                    #class_weight=class_weights, 
                    shuffle=True, 
                    callbacks=callbacks_list)
    
#     np.save(path+'acc.npy', history.history['accuracy'])
#     np.save(path+'val_acc.npy', history.history['val_accuracy'])
#     np.save(path+'loss.npy', history.history['loss'])
#     np.save(path+'val_loss.npy', history.history['val_loss'])
    
    model.load_weights(filepath)
    # evaluate the model
    #scores = model.evaluate(x_test, y_test, verbose=0)
    scores = model.evaluate(dataset_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    
    #predict = model.predict([x_test])
    predict = model.predict(dataset_test)[0]
    
    # ===================auc=========================
    n_classes = y_test.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], predict[:, i], )
        roc_auc[i] = auc(fpr[i], tpr[i])
    roc_auc["macro"] = roc_auc_score(y_test, predict, multi_class="ovo", average="macro")
    roc_auc["weighted"] = roc_auc_score(y_test, predict, multi_class="ovo", average="weighted")
    # ===================================================

    y_pre = np.argmax(predict, axis=1)
    y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pre, output_dict=True)
    df1 = pd.DataFrame(report).transpose()
    
    df1['auc'] = [roc_auc[0], roc_auc[1], roc_auc[2], " ", roc_auc["macro"], roc_auc["weighted"]]
    
    # Write it into csv format
    #df1.to_csv(path+'report.csv', index=True, header=True)
    
    cvpre.append(df1.loc['macro avg','precision'] * 100)
    cvrecall.append(df1.loc['macro avg','recall'] * 100)
    cvf1.append(df1.loc['macro avg','f1-score'] * 100)
    cvauc.append(df1.loc['macro avg','auc'] * 100)
    
#     data = confusion_matrix(y_test, y_pre)
#     names = ['normal', 'pneumonia', 'COVID-19']
#     df_cm = pd.DataFrame(data, columns=names, index=names)
#     df_cm.to_csv(path+'cm.csv', index=True, header=True)
    print("========================= 第"+ str(k+1) +"折结束 ============================")
    
print("accuracy：%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
print("precision：%.2f%% (+/- %.2f%%)" % (np.mean(cvpre), np.std(cvpre)))
print("recall：%.2f%% (+/- %.2f%%)" % (np.mean(cvrecall), np.std(cvrecall)))
print("f1-score：%.2f%% (+/- %.2f%%)" % (np.mean(cvf1), np.std(cvf1)))
print("auc：%.2f%% (+/- %.2f%%)" % (np.mean(cvauc), np.std(cvauc)))
# Out:
# ========================= 第1折开始 ============================
# Epoch 1/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8320 - CapsNet_loss: 0.8100 - Generator_loss: 0.0562 - CapsNet_accuracy: 0.2755
# Epoch 00001: val_CapsNet_accuracy improved from -inf to 0.35176, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 7s 132ms/step - loss: 0.8320 - CapsNet_loss: 0.8100 - Generator_loss: 0.0562 - CapsNet_accuracy: 0.2755 - val_loss: 0.8314 - val_CapsNet_loss: 0.8098 - val_Generator_loss: 0.0551 - val_CapsNet_accuracy: 0.3518
# Epoch 2/100
# 50/50 [==============================] - ETA: 0s - loss: 0.8312 - CapsNet_loss: 0.8092 - Generator_loss: 0.0560 - CapsNet_accuracy: 0.2327
# Epoch 00002: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.8312 - CapsNet_loss: 0.8092 - Generator_loss: 0.0560 - CapsNet_accuracy: 0.2327 - val_loss: 0.8271 - val_CapsNet_loss: 0.8056 - val_Generator_loss: 0.0549 - val_CapsNet_accuracy: 0.3518
# Epoch 3/100
# 50/50 [==============================] - ETA: 0s - loss: 0.6154 - CapsNet_loss: 0.5936 - Generator_loss: 0.0558 - CapsNet_accuracy: 0.1245
# Epoch 00003: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.6154 - CapsNet_loss: 0.5936 - Generator_loss: 0.0558 - CapsNet_accuracy: 0.1245 - val_loss: 0.5722 - val_CapsNet_loss: 0.5509 - val_Generator_loss: 0.0543 - val_CapsNet_accuracy: 0.3518
# Epoch 4/100
# 50/50 [==============================] - ETA: 0s - loss: 0.5293 - CapsNet_loss: 0.5080 - Generator_loss: 0.0545 - CapsNet_accuracy: 0.1182
# Epoch 00004: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.5293 - CapsNet_loss: 0.5080 - Generator_loss: 0.0545 - CapsNet_accuracy: 0.1182 - val_loss: 0.3736 - val_CapsNet_loss: 0.3534 - val_Generator_loss: 0.0515 - val_CapsNet_accuracy: 0.3518
# Epoch 5/100
# 50/50 [==============================] - ETA: 0s - loss: 0.4627 - CapsNet_loss: 0.4443 - Generator_loss: 0.0469 - CapsNet_accuracy: 0.0428
# Epoch 00005: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.4627 - CapsNet_loss: 0.4443 - Generator_loss: 0.0469 - CapsNet_accuracy: 0.0428 - val_loss: 0.3749 - val_CapsNet_loss: 0.3604 - val_Generator_loss: 0.0370 - val_CapsNet_accuracy: 0.3518
# Epoch 6/100
# 50/50 [==============================] - ETA: 0s - loss: 0.4138 - CapsNet_loss: 0.4012 - Generator_loss: 0.0322 - CapsNet_accuracy: 0.0642
# Epoch 00006: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.4138 - CapsNet_loss: 0.4012 - Generator_loss: 0.0322 - CapsNet_accuracy: 0.0642 - val_loss: 0.3461 - val_CapsNet_loss: 0.3351 - val_Generator_loss: 0.0281 - val_CapsNet_accuracy: 0.3518
# Epoch 7/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3883 - CapsNet_loss: 0.3764 - Generator_loss: 0.0305 - CapsNet_accuracy: 0.0843
# Epoch 00007: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3883 - CapsNet_loss: 0.3764 - Generator_loss: 0.0305 - CapsNet_accuracy: 0.0843 - val_loss: 0.3465 - val_CapsNet_loss: 0.3356 - val_Generator_loss: 0.0277 - val_CapsNet_accuracy: 0.3518
# Epoch 8/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3808 - CapsNet_loss: 0.3691 - Generator_loss: 0.0298 - CapsNet_accuracy: 0.1019
# Epoch 00008: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3808 - CapsNet_loss: 0.3691 - Generator_loss: 0.0298 - CapsNet_accuracy: 0.1019 - val_loss: 0.3474 - val_CapsNet_loss: 0.3366 - val_Generator_loss: 0.0276 - val_CapsNet_accuracy: 0.3518
# Epoch 9/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3752 - CapsNet_loss: 0.3636 - Generator_loss: 0.0296 - CapsNet_accuracy: 0.1019
# Epoch 00009: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3752 - CapsNet_loss: 0.3636 - Generator_loss: 0.0296 - CapsNet_accuracy: 0.1019 - val_loss: 0.3498 - val_CapsNet_loss: 0.3390 - val_Generator_loss: 0.0275 - val_CapsNet_accuracy: 0.3518
# Epoch 10/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3696 - CapsNet_loss: 0.3581 - Generator_loss: 0.0294 - CapsNet_accuracy: 0.1019
# Epoch 00010: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3696 - CapsNet_loss: 0.3581 - Generator_loss: 0.0294 - CapsNet_accuracy: 0.1019 - val_loss: 0.3538 - val_CapsNet_loss: 0.3431 - val_Generator_loss: 0.0274 - val_CapsNet_accuracy: 0.3518
# Epoch 11/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3624 - CapsNet_loss: 0.3510 - Generator_loss: 0.0292 - CapsNet_accuracy: 0.1107
# Epoch 00011: val_CapsNet_accuracy did not improve from 0.35176
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3624 - CapsNet_loss: 0.3510 - Generator_loss: 0.0292 - CapsNet_accuracy: 0.1107 - val_loss: 0.3611 - val_CapsNet_loss: 0.3503 - val_Generator_loss: 0.0274 - val_CapsNet_accuracy: 0.3518
# Epoch 12/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3511 - CapsNet_loss: 0.3398 - Generator_loss: 0.0288 - CapsNet_accuracy: 0.1182
# Epoch 00012: val_CapsNet_accuracy improved from 0.35176 to 0.39698, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 115ms/step - loss: 0.3511 - CapsNet_loss: 0.3398 - Generator_loss: 0.0288 - CapsNet_accuracy: 0.1182 - val_loss: 0.3729 - val_CapsNet_loss: 0.3622 - val_Generator_loss: 0.0273 - val_CapsNet_accuracy: 0.3970
# Epoch 13/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3335 - CapsNet_loss: 0.3224 - Generator_loss: 0.0282 - CapsNet_accuracy: 0.1849
# Epoch 00013: val_CapsNet_accuracy improved from 0.39698 to 0.56281, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.3335 - CapsNet_loss: 0.3224 - Generator_loss: 0.0282 - CapsNet_accuracy: 0.1849 - val_loss: 0.3735 - val_CapsNet_loss: 0.3630 - val_Generator_loss: 0.0268 - val_CapsNet_accuracy: 0.5628
# Epoch 14/100
# 50/50 [==============================] - ETA: 0s - loss: 0.3106 - CapsNet_loss: 0.3000 - Generator_loss: 0.0272 - CapsNet_accuracy: 0.3371
# Epoch 00014: val_CapsNet_accuracy improved from 0.56281 to 0.64322, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.3106 - CapsNet_loss: 0.3000 - Generator_loss: 0.0272 - CapsNet_accuracy: 0.3371 - val_loss: 0.3795 - val_CapsNet_loss: 0.3693 - val_Generator_loss: 0.0262 - val_CapsNet_accuracy: 0.6432
# Epoch 15/100
# 50/50 [==============================] - ETA: 0s - loss: 0.2833 - CapsNet_loss: 0.2731 - Generator_loss: 0.0260 - CapsNet_accuracy: 0.4906
# Epoch 00015: val_CapsNet_accuracy did not improve from 0.64322
# 50/50 [==============================] - 5s 109ms/step - loss: 0.2833 - CapsNet_loss: 0.2731 - Generator_loss: 0.0260 - CapsNet_accuracy: 0.4906 - val_loss: 0.3861 - val_CapsNet_loss: 0.3761 - val_Generator_loss: 0.0256 - val_CapsNet_accuracy: 0.6281
# Epoch 16/100
# 50/50 [==============================] - ETA: 0s - loss: 0.2502 - CapsNet_loss: 0.2404 - Generator_loss: 0.0250 - CapsNet_accuracy: 0.6013
# Epoch 00016: val_CapsNet_accuracy did not improve from 0.64322
# 50/50 [==============================] - 5s 109ms/step - loss: 0.2502 - CapsNet_loss: 0.2404 - Generator_loss: 0.0250 - CapsNet_accuracy: 0.6013 - val_loss: 0.3027 - val_CapsNet_loss: 0.2934 - val_Generator_loss: 0.0239 - val_CapsNet_accuracy: 0.6030
# Epoch 17/100
# 50/50 [==============================] - ETA: 0s - loss: 0.2207 - CapsNet_loss: 0.2110 - Generator_loss: 0.0246 - CapsNet_accuracy: 0.6528
# Epoch 00017: val_CapsNet_accuracy improved from 0.64322 to 0.65829, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.2207 - CapsNet_loss: 0.2110 - Generator_loss: 0.0246 - CapsNet_accuracy: 0.6528 - val_loss: 0.3725 - val_CapsNet_loss: 0.3632 - val_Generator_loss: 0.0238 - val_CapsNet_accuracy: 0.6583
# Epoch 18/100
# 50/50 [==============================] - ETA: 0s - loss: 0.2072 - CapsNet_loss: 0.1977 - Generator_loss: 0.0243 - CapsNet_accuracy: 0.6818
# Epoch 00018: val_CapsNet_accuracy improved from 0.65829 to 0.81910, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 115ms/step - loss: 0.2072 - CapsNet_loss: 0.1977 - Generator_loss: 0.0243 - CapsNet_accuracy: 0.6818 - val_loss: 0.1964 - val_CapsNet_loss: 0.1872 - val_Generator_loss: 0.0236 - val_CapsNet_accuracy: 0.8191
# Epoch 19/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1864 - CapsNet_loss: 0.1769 - Generator_loss: 0.0243 - CapsNet_accuracy: 0.7195
# Epoch 00019: val_CapsNet_accuracy improved from 0.81910 to 0.82412, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1864 - CapsNet_loss: 0.1769 - Generator_loss: 0.0243 - CapsNet_accuracy: 0.7195 - val_loss: 0.2617 - val_CapsNet_loss: 0.2523 - val_Generator_loss: 0.0238 - val_CapsNet_accuracy: 0.8241
# Epoch 20/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1610 - CapsNet_loss: 0.1516 - Generator_loss: 0.0240 - CapsNet_accuracy: 0.8038
# Epoch 00020: val_CapsNet_accuracy improved from 0.82412 to 0.88442, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1610 - CapsNet_loss: 0.1516 - Generator_loss: 0.0240 - CapsNet_accuracy: 0.8038 - val_loss: 0.1383 - val_CapsNet_loss: 0.1291 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8844
# Epoch 21/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1415 - CapsNet_loss: 0.1320 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8327
# Epoch 00021: val_CapsNet_accuracy improved from 0.88442 to 0.90452, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1415 - CapsNet_loss: 0.1320 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8327 - val_loss: 0.1219 - val_CapsNet_loss: 0.1127 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.9045
# Epoch 22/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1307 - CapsNet_loss: 0.1213 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8579
# Epoch 00022: val_CapsNet_accuracy improved from 0.90452 to 0.91960, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1307 - CapsNet_loss: 0.1213 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8579 - val_loss: 0.1151 - val_CapsNet_loss: 0.1059 - val_Generator_loss: 0.0234 - val_CapsNet_accuracy: 0.9196
# Epoch 23/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1216 - CapsNet_loss: 0.1121 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8679
# Epoch 00023: val_CapsNet_accuracy improved from 0.91960 to 0.92462, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1216 - CapsNet_loss: 0.1121 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8679 - val_loss: 0.1070 - val_CapsNet_loss: 0.0978 - val_Generator_loss: 0.0234 - val_CapsNet_accuracy: 0.9246
# Epoch 24/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1131 - CapsNet_loss: 0.1036 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8818
# Epoch 00024: val_CapsNet_accuracy improved from 0.92462 to 0.93467, saving model to model\cg-weights-best.h5
# 50/50 [==============================] - 6s 116ms/step - loss: 0.1131 - CapsNet_loss: 0.1036 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.8818 - val_loss: 0.1009 - val_CapsNet_loss: 0.0917 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.9347
# Epoch 25/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1061 - CapsNet_loss: 0.0966 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.8868
# Epoch 00025: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1061 - CapsNet_loss: 0.0966 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.8868 - val_loss: 0.0963 - val_CapsNet_loss: 0.0871 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.9246
# Epoch 26/100
# 50/50 [==============================] - ETA: 0s - loss: 0.1000 - CapsNet_loss: 0.0906 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.8969
# Epoch 00026: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1000 - CapsNet_loss: 0.0906 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.8969 - val_loss: 0.0943 - val_CapsNet_loss: 0.0851 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.9095
# Epoch 27/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0949 - CapsNet_loss: 0.0854 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.9082
# Epoch 00027: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0949 - CapsNet_loss: 0.0854 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.9082 - val_loss: 0.0936 - val_CapsNet_loss: 0.0844 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.9095
# Epoch 28/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0906 - CapsNet_loss: 0.0811 - Generator_loss: 0.0242 - CapsNet_accuracy: 0.9107
# Epoch 00028: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0906 - CapsNet_loss: 0.0811 - Generator_loss: 0.0242 - CapsNet_accuracy: 0
- val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 95/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0231 - CapsNet_loss: 0.0137 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00095: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0231 - CapsNet_loss: 0.0137 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0788 - val_CapsNet_loss: 0.0696 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 96/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0230 - CapsNet_loss: 0.0136 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00096: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0230 - CapsNet_loss: 0.0136 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0788 - val_CapsNet_loss: 0.0696 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 97/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0229 - CapsNet_loss: 0.0135 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00097: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0229 - CapsNet_loss: 0.0135 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0788 - val_CapsNet_loss: 0.0696 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 98/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0229 - CapsNet_loss: 0.0134 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00098: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0229 - CapsNet_loss: 0.0134 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0788 - val_CapsNet_loss: 0.0696 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 99/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0228 - CapsNet_loss: 0.0133 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00099: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0228 - CapsNet_loss: 0.0133 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0787 - val_CapsNet_loss: 0.0695 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# Epoch 100/100
# 50/50 [==============================] - ETA: 0s - loss: 0.0224 - CapsNet_loss: 0.0130 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937
# Epoch 00100: val_CapsNet_accuracy did not improve from 0.93467
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0224 - CapsNet_loss: 0.0130 - Generator_loss: 0.0241 - CapsNet_accuracy: 0.9937 - val_loss: 0.0787 - val_CapsNet_loss: 0.0695 - val_Generator_loss: 0.0235 - val_CapsNet_accuracy: 0.8995
# CapsNet_loss: 9.17%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-fa8b69bccaa2> in <module>
#      93     roc_auc = dict()
#      94     for i in range(num_classes):
# ---> 95         fpr[i], tpr[i], _ = roc_curve(y_test[:, i], predict[:, i], )
#      96         roc_auc[i] = auc(fpr[i], tpr[i])
#      97     roc_auc["macro"] = roc_auc_score(y_test, predict, multi_class="ovo", average="macro")
#
# TypeError: list indices must be integers or slices, not tuple

# %%
X = np.load("newData/image.npy")
Y = np.load("newData/label.npy")

y = utils.to_categorical(Y, num_classes)
    
dataset = tf.data.Dataset.from_tensor_slices((X, y))
dataset = dataset.map(generator_, num_parallel_calls=16)
dataset = dataset.batch(batch_size)
dataset = dataset.prefetch(-1)

# %%
#predict = model.predict(dataset)[0]
predict = np.array([])
for i, data in enumerate(dataset):
    if i == 0:
        predict = model.predict(data)[0]
    else:
        predict = np.concatenate((predict, model.predict(data)[0]))

y = label_binarize(Y, classes=[0, 1, 2])
n_classes = y.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y[:, i], predict[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])
roc_auc["macro"] = roc_auc_score(y, predict, multi_class="ovo", average="macro")
roc_auc["weighted"] = roc_auc_score(y, predict, multi_class="ovo", average="weighted")


y_pre = np.argmax(predict, axis=1)
report = classification_report(Y, y_pre, output_dict=True)
df1 = pd.DataFrame(report).transpose()
df1['auc'] = [roc_auc[0], roc_auc[1], roc_auc[2], '', roc_auc["macro"], roc_auc["weighted"]]
df1
# Out:
#               precision    recall  f1-score      support       auc
# 0              0.852162  0.911260  0.880721  1341.000000  0.951683
# 1              0.874308  0.822305  0.847510  1345.000000  0.938098
# 2              0.947767  0.937500  0.942606  1200.000000  0.987714
# accuracy       0.888574  0.888574  0.888574     0.888574
# macro avg      0.891413  0.890355  0.890279  3886.000000  0.959165
# weighted avg   0.889350  0.888574  0.888336  3886.000000  0.958107
