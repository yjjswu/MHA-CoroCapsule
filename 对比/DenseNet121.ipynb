# %%
from __future__ import print_function
from tensorflow.keras import backend as K
from tensorflow.keras import layers, Sequential, regularizers
from tensorflow.keras.layers import Layer
from tensorflow.keras import activations
from tensorflow.keras import utils
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *

from tensorflow.keras.callbacks import LearningRateScheduler

#import keras
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers

from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

from numpy import interp

import math
from itertools import cycle
import numpy as np
import pandas as pd
import random
import seaborn as sn
from matplotlib import pyplot as plt

from evaluation import compute_performance_measures

from utils import *
from layers import *

K.set_image_data_format('channels_last')

config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  #按需分配显存
session = tf.compat.v1.Session(config=config)

# tf.random.set_seed(111111)
# np.random.seed(111111)
# random.seed(111111)

tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.keras.applications.densenet import DenseNet121

def create_model(inputs):
    model_densenet = DenseNet121(include_top=False, weights=None, input_shape=(128, 128, 3))
    model_densenet.load_weights('densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5')
    for layers in model_densenet.layers:
        layers.trainable = True

    x = GlobalAveragePooling2D(name='final_pooling')(model_densenet.output)
    x = Dense(3, activation='softmax', name='fc')(x)
    model = Model(inputs=model_densenet.input, outputs=x, name='densenet121_pretrain')
    return model

# %%
inputs = Input(shape=(128, 128, 3))
model = create_model(inputs)
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "densenet121_pretrain"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 134, 134, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 64, 64, 64)   9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 64, 64, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 64, 64, 64)   0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 66, 66, 64)   0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 32, 32, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 32, 32, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 32, 32, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 32, 32, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 32, 32, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 32, 32, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 32, 32, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 32, 32, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 32, 32, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 32, 32, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 32, 32, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 32, 32, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 32, 32, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 32, 32, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 32, 32, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 32, 32, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 32, 32, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 32, 32, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 32, 32, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 32, 32, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 32, 32, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 32, 32, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 32, 32, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 32, 32, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 32, 32, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 32, 32, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 32, 32, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 32, 32, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 32, 32, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 32, 32, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 32, 32, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 32, 32, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 32, 32, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 16, 16, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 16, 16, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 16, 16, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 16, 16, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 16, 16, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 16, 16, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 16, 16, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 16, 16, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 16, 16, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 16, 16, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 16, 16, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 16, 16, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 16, 16, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 16, 16, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 16, 16, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 16, 16, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 16, 16, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 16, 16, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 16, 16, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 16, 16, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 16, 16, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 16, 16, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 16, 16, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 16, 16, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 16, 16, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 16, 16, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 16, 16, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 16, 16, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 16, 16, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 16, 16, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 16, 16, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 16, 16, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 16, 16, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 16, 16, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 16, 16, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 16, 16, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 16, 16, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 16, 16, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 16, 16, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 16, 16, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 16, 16, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 16, 16, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 16, 16, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 16, 16, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 16, 16, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 16, 16, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 16, 16, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 16, 16, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 16, 16, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 16, 16, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 16, 16, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 16, 16, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 16, 16, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 16, 16, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 16, 16, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 16, 16, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 16, 16, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 16, 16, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 16, 16, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 16, 16, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 16, 16, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 8, 8, 256)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 8, 8, 256)    0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 8, 8, 128)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 8, 8, 288)    0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 8, 8, 288)    1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 8, 8, 288)    0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 8, 8, 128)    36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 8, 8, 128)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 8, 8, 320)    0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 8, 8, 320)    1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 8, 8, 320)    0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 8, 8, 128)    40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 8, 8, 128)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 8, 8, 352)    0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 8, 8, 352)    1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 8, 8, 352)    0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 8, 8, 128)    45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 8, 8, 128)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 8, 8, 384)    0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 8, 8, 384)    1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 8, 8, 384)    0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 8, 8, 128)    49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 8, 8, 128)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 8, 8, 416)    0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 8, 8, 416)    1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 8, 8, 416)    0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 8, 8, 128)    53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 8, 8, 128)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 8, 8, 448)    0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 8, 8, 448)    1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 8, 8, 448)    0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 8, 8, 128)    57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 8, 8, 128)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 8, 8, 480)    0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 8, 8, 480)    1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 8, 8, 480)    0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 8, 8, 128)    61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 8, 8, 128)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 8, 8, 512)    0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 8, 8, 512)    2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 8, 8, 512)    0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 8, 8, 128)    65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 8, 8, 128)    512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 8, 8, 128)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 8, 8, 32)     36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 8, 8, 544)    0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 8, 8, 544)    2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 8, 8, 544)    0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 8, 8, 128)    69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 8, 8, 576)    0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 8, 8, 576)    2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 8, 8, 576)    0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 8, 8, 128)    73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 8, 8, 608)    0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 8, 8, 608)    2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 8, 8, 608)    0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 8, 8, 128)    77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 8, 8, 128)    512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 8, 8, 128)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 8, 8, 640)    0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 8, 8, 640)    2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block7_0_bn (BatchNormali (None, 4, 4, 704)    2816        conv5_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_relu (Activation (None, 4, 4, 704)    0           conv5_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_conv (Conv2D)    (None, 4, 4, 128)    90112       conv5_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_bn (BatchNormali (None, 4, 4, 128)    512         conv5_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_relu (Activation (None, 4, 4, 128)    0           conv5_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_2_conv (Conv2D)    (None, 4, 4, 32)     36864       conv5_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_concat (Concatenat (None, 4, 4, 736)    0           conv5_block6_concat[0][0]
#                                                                  conv5_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_bn (BatchNormali (None, 4, 4, 736)    2944        conv5_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_relu (Activation (None, 4, 4, 736)    0           conv5_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_conv (Conv2D)    (None, 4, 4, 128)    94208       conv5_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_bn (BatchNormali (None, 4, 4, 128)    512         conv5_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_relu (Activation (None, 4, 4, 128)    0           conv5_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_2_conv (Conv2D)    (None, 4, 4, 32)     36864       conv5_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_concat (Concatenat (None, 4, 4, 768)    0           conv5_block7_concat[0][0]
#                                                                  conv5_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_bn (BatchNormali (None, 4, 4, 768)    3072        conv5_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_relu (Activation (None, 4, 4, 768)    0           conv5_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_conv (Conv2D)    (None, 4, 4, 128)    98304       conv5_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_bn (BatchNormali (None, 4, 4, 128)    512         conv5_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_relu (Activation (None, 4, 4, 128)    0           conv5_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_2_conv (Conv2D)    (None, 4, 4, 32)     36864       conv5_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_concat (Concatenat (None, 4, 4, 800)    0           conv5_block8_concat[0][0]
#                                                                  conv5_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_bn (BatchNormal (None, 4, 4, 800)    3200        conv5_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_relu (Activatio (None, 4, 4, 800)    0           conv5_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_conv (Conv2D)   (None, 4, 4, 128)    102400      conv5_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_concat (Concatena (None, 4, 4, 832)    0           conv5_block9_concat[0][0]
#                                                                  conv5_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormal (None, 4, 4, 832)    3328        conv5_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_relu (Activatio (None, 4, 4, 832)    0           conv5_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)   (None, 4, 4, 128)    106496      conv5_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_concat (Concatena (None, 4, 4, 864)    0           conv5_block10_concat[0][0]
#                                                                  conv5_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormal (None, 4, 4, 864)    3456        conv5_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_relu (Activatio (None, 4, 4, 864)    0           conv5_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)   (None, 4, 4, 128)    110592      conv5_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_concat (Concatena (None, 4, 4, 896)    0           conv5_block11_concat[0][0]
#                                                                  conv5_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormal (None, 4, 4, 896)    3584        conv5_block12_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_relu (Activatio (None, 4, 4, 896)    0           conv5_block13_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)   (None, 4, 4, 128)    114688      conv5_block13_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_concat (Concatena (None, 4, 4, 928)    0           conv5_block12_concat[0][0]
#                                                                  conv5_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormal (None, 4, 4, 928)    3712        conv5_block13_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_relu (Activatio (None, 4, 4, 928)    0           conv5_block14_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)   (None, 4, 4, 128)    118784      conv5_block14_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_concat (Concatena (None, 4, 4, 960)    0           conv5_block13_concat[0][0]
#                                                                  conv5_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormal (None, 4, 4, 960)    3840        conv5_block14_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_relu (Activatio (None, 4, 4, 960)    0           conv5_block15_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)   (None, 4, 4, 128)    122880      conv5_block15_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_concat (Concatena (None, 4, 4, 992)    0           conv5_block14_concat[0][0]
#                                                                  conv5_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormal (None, 4, 4, 992)    3968        conv5_block15_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_relu (Activatio (None, 4, 4, 992)    0           conv5_block16_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)   (None, 4, 4, 128)    126976      conv5_block16_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormal (None, 4, 4, 128)    512         conv5_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_relu (Activatio (None, 4, 4, 128)    0           conv5_block16_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)   (None, 4, 4, 32)     36864       conv5_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_concat (Concatena (None, 4, 4, 1024)   0           conv5_block15_concat[0][0]
#                                                                  conv5_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 4, 4, 1024)   4096        conv5_block16_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 4, 4, 1024)   0           bn[0][0]
# __________________________________________________________________________________________________
# final_pooling (GlobalAveragePoo (None, 1024)         0           relu[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 3)            3075        final_pooling[0][0]
# ==================================================================================================
# Total params: 7,040,579
# Trainable params: 6,956,931
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
#learning decay rate schedule
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.5 
    epochs_drop = 20  
    lrate = initial_lrate * math.pow(drop, math.floor((1 + epoch) / epochs_drop))
    return lrate

# %%
batch_size = 16  
num_classes = 3
epochs = 100

images= np.load("data/image.npy")
labels= np.load("data/label.npy")

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

# define 5-fold cross validation test harness
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=3)
cvscores = []
cvpre = []
cvrecall  =[]
cvf1 = []
cvauc = []

for k, (train, test) in enumerate(kfold.split(images, labels)):
    
    path = "model/"
    
    x_train = images[train]
    x_test = images[test]
    y_train = labels[train]
    y_test = labels[test]
    
#     np.save(path + 'data/x_train.npy', x_train)
#     np.save(path + 'data/y_train.npy', y_train)
#     np.save(path + 'data/x_test.npy', x_test)
#     np.save(path + 'data/y_test.npy', y_test)
    
    #class weights to handle class imbalance
    class_weights = {0: 1-np.count_nonzero(y_train==0)/len(y_train), 
                     1: 1-np.count_nonzero(y_train==1)/len(y_train), 
                     2: 1-np.count_nonzero(y_train==2)/len(y_train)}

    # 将整型标签转为onehot
    y_train = utils.to_categorical(y_train, num_classes)
    y_test = utils.to_categorical(y_test, num_classes)
    
    
    # The best model is selected based on the loss value on the validation set
    filepath = path+"denseNet121-weights-best.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    # learning schedule callback
    lrate = LearningRateScheduler(step_decay)

    callbacks_list = [checkpoint, lrate]
    

    inputs = Input(shape=(128, 128, 3))
    #===================================Model======================================
    model = create_model(inputs)   
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
    
    print("========================= 第"+ str(k+1) +"折开始 ============================")
    history = model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs, 
                    verbose=2,
                    #validation_split=0.1,
                    validation_data=(x_test, y_test),
                    class_weight=class_weights, 
                    shuffle=True, 
                    callbacks=callbacks_list)
    
#     np.save(path+'acc.npy', history.history['accuracy'])
#     np.save(path+'val_acc.npy', history.history['val_accuracy'])
#     np.save(path+'loss.npy', history.history['loss'])
#     np.save(path+'val_loss.npy', history.history['val_loss'])
    
    model.load_weights(filepath)
    # evaluate the model
    scores = model.evaluate(x_test, y_test, verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    
    predict = model.predict([x_test])
    
    # ===================auc=========================
    n_classes = y_test.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], predict[:, i], )
        roc_auc[i] = auc(fpr[i], tpr[i])
    roc_auc["macro"] = roc_auc_score(y_test, predict, multi_class="ovo", average="macro")
    roc_auc["weighted"] = roc_auc_score(y_test, predict, multi_class="ovo", average="weighted")
    # ===================================================

    y_pre = np.argmax(predict, axis=1)
    y_test = np.argmax(y_test, axis=1)

    report = classification_report(y_test, y_pre, output_dict=True)
    df1 = pd.DataFrame(report).transpose()
    
    df1['auc'] = [roc_auc[0], roc_auc[1], roc_auc[2], " ", roc_auc["macro"], roc_auc["weighted"]]
    
    # Write it into csv format
    #df1.to_csv(path+'report.csv', index=True, header=True)
    
    cvpre.append(df1.loc['macro avg','precision'] * 100)
    cvrecall.append(df1.loc['macro avg','recall'] * 100)
    cvf1.append(df1.loc['macro avg','f1-score'] * 100)
    cvauc.append(df1.loc['macro avg','auc'] * 100)
    
#     data = confusion_matrix(y_test, y_pre)
#     names = ['normal', 'pneumonia', 'COVID-19']
#     df_cm = pd.DataFrame(data, columns=names, index=names)
#     df_cm.to_csv(path+'cm.csv', index=True, header=True)
    print("========================= 第"+ str(k+1) +"折结束 ============================")
    
print("accuracy：%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
print("precision：%.2f%% (+/- %.2f%%)" % (np.mean(cvpre), np.std(cvpre)))
print("recall：%.2f%% (+/- %.2f%%)" % (np.mean(cvrecall), np.std(cvrecall)))
print("f1-score：%.2f%% (+/- %.2f%%)" % (np.mean(cvf1), np.std(cvf1)))
print("auc：%.2f%% (+/- %.2f%%)" % (np.mean(cvauc), np.std(cvauc)))
# Out:
# ========================= 第1折开始 ============================
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.50251, saving model to model\denseNet121-weights-best.h5
# 50/50 - 11s - loss: 1.0817 - accuracy: 0.3975 - val_loss: 2.0566 - val_accuracy: 0.5025
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.50251 to 0.51256, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.8187 - accuracy: 0.4692 - val_loss: 1.6121 - val_accuracy: 0.5126
# Epoch 3/100
#
# Epoch 00003: val_accuracy did not improve from 0.51256
# 50/50 - 5s - loss: 0.6254 - accuracy: 0.5799 - val_loss: 1.2778 - val_accuracy: 0.5075
# Epoch 4/100
#
# Epoch 00004: val_accuracy did not improve from 0.51256
# 50/50 - 5s - loss: 0.5201 - accuracy: 0.6377 - val_loss: 1.1802 - val_accuracy: 0.4874
# Epoch 5/100
#
# Epoch 00005: val_accuracy did not improve from 0.51256
# 50/50 - 5s - loss: 0.4453 - accuracy: 0.7283 - val_loss: 1.1176 - val_accuracy: 0.5075
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.51256 to 0.54271, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.4049 - accuracy: 0.7597 - val_loss: 1.0739 - val_accuracy: 0.5427
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.54271 to 0.57789, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3643 - accuracy: 0.8025 - val_loss: 0.9554 - val_accuracy: 0.5779
# Epoch 8/100
#
# Epoch 00008: val_accuracy improved from 0.57789 to 0.59799, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3365 - accuracy: 0.8314 - val_loss: 0.8551 - val_accuracy: 0.5980
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.59799 to 0.64824, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3248 - accuracy: 0.8302 - val_loss: 0.7884 - val_accuracy: 0.6482
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.64824 to 0.69347, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2932 - accuracy: 0.8516 - val_loss: 0.6753 - val_accuracy: 0.6935
# Epoch 11/100
#
# Epoch 00011: val_accuracy improved from 0.69347 to 0.74372, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2727 - accuracy: 0.8780 - val_loss: 0.5829 - val_accuracy: 0.7437
# Epoch 12/100
#
# Epoch 00012: val_accuracy did not improve from 0.74372
# 50/50 - 5s - loss: 0.2675 - accuracy: 0.8792 - val_loss: 0.5365 - val_accuracy: 0.7437
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.74372 to 0.80905, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2367 - accuracy: 0.9082 - val_loss: 0.4705 - val_accuracy: 0.8090
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.80905 to 0.85930, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2334 - accuracy: 0.9019 - val_loss: 0.4017 - val_accuracy: 0.8593
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.85930
# 50/50 - 5s - loss: 0.2208 - accuracy: 0.9182 - val_loss: 0.3872 - val_accuracy: 0.8543
# Epoch 16/100
#
# Epoch 00016: val_accuracy improved from 0.85930 to 0.89447, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2176 - accuracy: 0.9107 - val_loss: 0.3656 - val_accuracy: 0.8945
# Epoch 17/100
#
# Epoch 00017: val_accuracy improved from 0.89447 to 0.90452, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2053 - accuracy: 0.9258 - val_loss: 0.3386 - val_accuracy: 0.9045
# Epoch 18/100
#
# Epoch 00018: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1956 - accuracy: 0.9296 - val_loss: 0.3463 - val_accuracy: 0.8744
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.2010 - accuracy: 0.9170 - val_loss: 0.3543 - val_accuracy: 0.9045
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1890 - accuracy: 0.9233 - val_loss: 0.3286 - val_accuracy: 0.9045
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1800 - accuracy: 0.9346 - val_loss: 0.3357 - val_accuracy: 0.8945
# Epoch 22/100
#
# Epoch 00022: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1679 - accuracy: 0.9396 - val_loss: 0.3233 - val_accuracy: 0.8894
# Epoch 23/100
#
# Epoch 00023: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1708 - accuracy: 0.9371 - val_loss: 0.3330 - val_accuracy: 0.8844
# Epoch 24/100
#
# Epoch 00024: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1618 - accuracy: 0.9472 - val_loss: 0.3006 - val_accuracy: 0.9045
# Epoch 25/100
#
# Epoch 00025: val_accuracy improved from 0.90452 to 0.91457, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1637 - accuracy: 0.9346 - val_loss: 0.3093 - val_accuracy: 0.9146
# Epoch 26/100
#
# Epoch 00026: val_accuracy improved from 0.91457 to 0.91960, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1702 - accuracy: 0.9472 - val_loss: 0.2996 - val_accuracy: 0.9196
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1716 - accuracy: 0.9321 - val_loss: 0.3309 - val_accuracy: 0.8945
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1576 - accuracy: 0.9535 - val_loss: 0.2984 - val_accuracy: 0.9045
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1516 - accuracy: 0.9610 - val_loss: 0.2910 - val_accuracy: 0.9146
# Epoch 30/100
#
# Epoch 00030: val_accuracy improved from 0.91960 to 0.92462, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1640 - accuracy: 0.9346 - val_loss: 0.2894 - val_accuracy: 0.9246
# Epoch 31/100
#
# Epoch 00031: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1380 - accuracy: 0.9635 - val_loss: 0.2914 - val_accuracy: 0.9045
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1566 - accuracy: 0.9434 - val_loss: 0.2759 - val_accuracy: 0.9196
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1530 - accuracy: 0.9459 - val_loss: 0.2802 - val_accuracy: 0.9146
# Epoch 34/100
#
# Epoch 00034: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1451 - accuracy: 0.9535 - val_loss: 0.2804 - val_accuracy: 0.9095
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1333 - accuracy: 0.9623 - val_loss: 0.2816 - val_accuracy: 0.9196
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1460 - accuracy: 0.9522 - val_loss: 0.2735 - val_accuracy: 0.9196
# Epoch 37/100
#
# Epoch 00037: val_accuracy improved from 0.92462 to 0.93467, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1411 - accuracy: 0.9597 - val_loss: 0.2829 - val_accuracy: 0.9347
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1326 - accuracy: 0.9560 - val_loss: 0.2827 - val_accuracy: 0.9246
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1386 - accuracy: 0.9535 - val_loss: 0.2804 - val_accuracy: 0.9196
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1176 - accuracy: 0.9698 - val_loss: 0.2646 - val_accuracy: 0.9296
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1300 - accuracy: 0.9522 - val_loss: 0.2638 - val_accuracy: 0.9246
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1377 - accuracy: 0.9472 - val_loss: 0.2682 - val_accuracy: 0.9246
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1143 - accuracy: 0.9711 - val_loss: 0.2645 - val_accuracy: 0.9196
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1420 - accuracy: 0.9572 - val_loss: 0.2594 - val_accuracy: 0.9196
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1243 - accuracy: 0.9635 - val_loss: 0.2578 - val_accuracy: 0.9296
# Epoch 46/100
#
# Epoch 00046: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1201 - accuracy: 0.9635 - val_loss: 0.2574 - val_accuracy: 0.9296
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1224 - accuracy: 0.9648 - val_loss: 0.2629 - val_accuracy: 0.9347
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1258 - accuracy: 0.9648 - val_loss: 0.2556 - val_accuracy: 0.9246
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1301 - accuracy: 0.9572 - val_loss: 0.2579 - val_accuracy: 0.9246
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1281 - accuracy: 0.9547 - val_loss: 0.2522 - val_accuracy: 0.9246
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1202 - accuracy: 0.9686 - val_loss: 0.2434 - val_accuracy: 0.9246
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1188 - accuracy: 0.9635 - val_loss: 0.2477 - val_accuracy: 0.9347
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1192 - accuracy: 0.9635 - val_loss: 0.2531 - val_accuracy: 0.9246
# Epoch 54/100
#
# Epoch 00054: val_accuracy improved from 0.93467 to 0.94472, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1194 - accuracy: 0.9673 - val_loss: 0.2516 - val_accuracy: 0.9447
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1176 - accuracy: 0.9660 - val_loss: 0.2529 - val_accuracy: 0.9196
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1103 - accuracy: 0.9635 - val_loss: 0.2522 - val_accuracy: 0.9246
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1200 - accuracy: 0.9610 - val_loss: 0.2484 - val_accuracy: 0.9347
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1149 - accuracy: 0.9711 - val_loss: 0.2513 - val_accuracy: 0.9397
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1074 - accuracy: 0.9673 - val_loss: 0.2466 - val_accuracy: 0.9447
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1096 - accuracy: 0.9761 - val_loss: 0.2466 - val_accuracy: 0.9347
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1111 - accuracy: 0.9698 - val_loss: 0.2458 - val_accuracy: 0.9296
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1144 - accuracy: 0.9686 - val_loss: 0.2441 - val_accuracy: 0.9397
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1078 - accuracy: 0.9698 - val_loss: 0.2434 - val_accuracy: 0.9296
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1119 - accuracy: 0.9673 - val_loss: 0.2422 - val_accuracy: 0.9246
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1109 - accuracy: 0.9686 - val_loss: 0.2412 - val_accuracy: 0.9296
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1221 - accuracy: 0.9610 - val_loss: 0.2401 - val_accuracy: 0.9196
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1128 - accuracy: 0.9660 - val_loss: 0.2405 - val_accuracy: 0.9246
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1180 - accuracy: 0.9673 - val_loss: 0.2406 - val_accuracy: 0.9296
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1073 - accuracy: 0.9723 - val_loss: 0.2391 - val_accuracy: 0.9347
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1157 - accuracy: 0.9635 - val_loss: 0.2377 - val_accuracy: 0.9296
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1252 - accuracy: 0.9497 - val_loss: 0.2369 - val_accuracy: 0.9447
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1013 - accuracy: 0.9748 - val_loss: 0.2392 - val_accuracy: 0.9447
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1072 - accuracy: 0.9761 - val_loss: 0.2371 - val_accuracy: 0.9397
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1105 - accuracy: 0.9698 - val_loss: 0.2394 - val_accuracy: 0.9397
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1010 - accuracy: 0.9711 - val_loss: 0.2408 - val_accuracy: 0.9347
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1141 - accuracy: 0.9761 - val_loss: 0.2398 - val_accuracy: 0.9246
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1343 - accuracy: 0.9560 - val_loss: 0.2418 - val_accuracy: 0.9296
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1176 - accuracy: 0.9522 - val_loss: 0.2370 - val_accuracy: 0.9246
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1079 - accuracy: 0.9761 - val_loss: 0.2364 - val_accuracy: 0.9246
# Epoch 80/100
#
# Epoch 00080: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1101 - accuracy: 0.9748 - val_loss: 0.2362 - val_accuracy: 0.9196
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1017 - accuracy: 0.9748 - val_loss: 0.2356 - val_accuracy: 0.9347
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1125 - accuracy: 0.9698 - val_loss: 0.2353 - val_accuracy: 0.9296
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1002 - accuracy: 0.9774 - val_loss: 0.2350 - val_accuracy: 0.9296
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1082 - accuracy: 0.9774 - val_loss: 0.2341 - val_accuracy: 0.9296
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1065 - accuracy: 0.9698 - val_loss: 0.2358 - val_accuracy: 0.9196
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1019 - accuracy: 0.9761 - val_loss: 0.2350 - val_accuracy: 0.9246
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1044 - accuracy: 0.9736 - val_loss: 0.2353 - val_accuracy: 0.9296
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1130 - accuracy: 0.9648 - val_loss: 0.2355 - val_accuracy: 0.9246
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1002 - accuracy: 0.9786 - val_loss: 0.2359 - val_accuracy: 0.9296
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1175 - accuracy: 0.9572 - val_loss: 0.2350 - val_accuracy: 0.9397
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.0986 - accuracy: 0.9774 - val_loss: 0.2339 - val_accuracy: 0.9246
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1075 - accuracy: 0.9673 - val_loss: 0.2347 - val_accuracy: 0.9246
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1028 - accuracy: 0.9711 - val_loss: 0.2337 - val_accuracy: 0.9296
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1167 - accuracy: 0.9635 - val_loss: 0.2344 - val_accuracy: 0.9246
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1029 - accuracy: 0.9698 - val_loss: 0.2341 - val_accuracy: 0.9196
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1109 - accuracy: 0.9648 - val_loss: 0.2323 - val_accuracy: 0.9296
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1008 - accuracy: 0.9774 - val_loss: 0.2322 - val_accuracy: 0.9347
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.0947 - accuracy: 0.9874 - val_loss: 0.2323 - val_accuracy: 0.9196
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1116 - accuracy: 0.9673 - val_loss: 0.2325 - val_accuracy: 0.9296
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.94472
# 50/50 - 5s - loss: 0.1009 - accuracy: 0.9736 - val_loss: 0.2334 - val_accuracy: 0.9246
# accuracy: 94.47%
# ========================= 第1折结束 ============================
# ========================= 第2折开始 ============================
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.26633, saving model to model\denseNet121-weights-best.h5
# 50/50 - 7s - loss: 1.0404 - accuracy: 0.3660 - val_loss: 1.6350 - val_accuracy: 0.2663
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.26633 to 0.36683, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.7796 - accuracy: 0.4591 - val_loss: 1.4190 - val_accuracy: 0.3668
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.36683 to 0.39196, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.6265 - accuracy: 0.5535 - val_loss: 1.3191 - val_accuracy: 0.3920
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.39196 to 0.41709, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.5473 - accuracy: 0.6377 - val_loss: 1.2305 - val_accuracy: 0.4171
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.41709 to 0.45226, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.4740 - accuracy: 0.7069 - val_loss: 1.1164 - val_accuracy: 0.4523
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.45226 to 0.49749, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.4493 - accuracy: 0.7283 - val_loss: 1.0219 - val_accuracy: 0.4975
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.49749 to 0.58794, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3904 - accuracy: 0.7811 - val_loss: 0.8949 - val_accuracy: 0.5879
# Epoch 8/100
#
# Epoch 00008: val_accuracy improved from 0.58794 to 0.62814, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3639 - accuracy: 0.8025 - val_loss: 0.8658 - val_accuracy: 0.6281
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.62814 to 0.69849, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3402 - accuracy: 0.8126 - val_loss: 0.7163 - val_accuracy: 0.6985
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.69849 to 0.76382, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3118 - accuracy: 0.8465 - val_loss: 0.6293 - val_accuracy: 0.7638
# Epoch 11/100
#
# Epoch 00011: val_accuracy did not improve from 0.76382
# 50/50 - 5s - loss: 0.3064 - accuracy: 0.8327 - val_loss: 0.5797 - val_accuracy: 0.7487
# Epoch 12/100
#
# Epoch 00012: val_accuracy improved from 0.76382 to 0.79899, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2783 - accuracy: 0.8692 - val_loss: 0.5343 - val_accuracy: 0.7990
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.79899 to 0.87437, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2572 - accuracy: 0.8818 - val_loss: 0.4204 - val_accuracy: 0.8744
# Epoch 14/100
#
# Epoch 00014: val_accuracy did not improve from 0.87437
# 50/50 - 5s - loss: 0.2482 - accuracy: 0.8956 - val_loss: 0.3905 - val_accuracy: 0.8693
# Epoch 15/100
#
# Epoch 00015: val_accuracy improved from 0.87437 to 0.89447, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2369 - accuracy: 0.8931 - val_loss: 0.3797 - val_accuracy: 0.8945
# Epoch 16/100
#
# Epoch 00016: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.2353 - accuracy: 0.8918 - val_loss: 0.3671 - val_accuracy: 0.8744
# Epoch 17/100
#
# Epoch 00017: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.2169 - accuracy: 0.9069 - val_loss: 0.3676 - val_accuracy: 0.8744
# Epoch 18/100
#
# Epoch 00018: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.2148 - accuracy: 0.9069 - val_loss: 0.3474 - val_accuracy: 0.8945
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.2110 - accuracy: 0.9006 - val_loss: 0.3269 - val_accuracy: 0.8844
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.1987 - accuracy: 0.9220 - val_loss: 0.3250 - val_accuracy: 0.8945
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.89447
# 50/50 - 5s - loss: 0.1896 - accuracy: 0.9157 - val_loss: 0.3208 - val_accuracy: 0.8945
# Epoch 22/100
#
# Epoch 00022: val_accuracy improved from 0.89447 to 0.90452, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1890 - accuracy: 0.9258 - val_loss: 0.3130 - val_accuracy: 0.9045
# Epoch 23/100
#
# Epoch 00023: val_accuracy improved from 0.90452 to 0.90955, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1763 - accuracy: 0.9333 - val_loss: 0.3042 - val_accuracy: 0.9095
# Epoch 24/100
#
# Epoch 00024: val_accuracy improved from 0.90955 to 0.91960, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1752 - accuracy: 0.9409 - val_loss: 0.3015 - val_accuracy: 0.9196
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1769 - accuracy: 0.9384 - val_loss: 0.2900 - val_accuracy: 0.9146
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1791 - accuracy: 0.9296 - val_loss: 0.2938 - val_accuracy: 0.8945
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1742 - accuracy: 0.9308 - val_loss: 0.2817 - val_accuracy: 0.9095
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1616 - accuracy: 0.9459 - val_loss: 0.2777 - val_accuracy: 0.9095
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1644 - accuracy: 0.9409 - val_loss: 0.2841 - val_accuracy: 0.9045
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.91960
# 50/50 - 5s - loss: 0.1726 - accuracy: 0.9346 - val_loss: 0.2782 - val_accuracy: 0.9146
# Epoch 31/100
#
# Epoch 00031: val_accuracy improved from 0.91960 to 0.92462, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1516 - accuracy: 0.9509 - val_loss: 0.2664 - val_accuracy: 0.9246
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1645 - accuracy: 0.9409 - val_loss: 0.2720 - val_accuracy: 0.9146
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1630 - accuracy: 0.9371 - val_loss: 0.2720 - val_accuracy: 0.9246
# Epoch 34/100
#
# Epoch 00034: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1524 - accuracy: 0.9447 - val_loss: 0.2599 - val_accuracy: 0.9146
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.92462
# 50/50 - 5s - loss: 0.1394 - accuracy: 0.9535 - val_loss: 0.2575 - val_accuracy: 0.9196
# Epoch 36/100
#
# Epoch 00036: val_accuracy improved from 0.92462 to 0.93467, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1549 - accuracy: 0.9447 - val_loss: 0.2644 - val_accuracy: 0.9347
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1580 - accuracy: 0.9333 - val_loss: 0.2574 - val_accuracy: 0.9246
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1518 - accuracy: 0.9409 - val_loss: 0.2526 - val_accuracy: 0.9296
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1423 - accuracy: 0.9497 - val_loss: 0.2514 - val_accuracy: 0.9246
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1290 - accuracy: 0.9623 - val_loss: 0.2495 - val_accuracy: 0.9296
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1536 - accuracy: 0.9384 - val_loss: 0.2481 - val_accuracy: 0.9296
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1499 - accuracy: 0.9371 - val_loss: 0.2454 - val_accuracy: 0.9347
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.93467
# 50/50 - 5s - loss: 0.1275 - accuracy: 0.9572 - val_loss: 0.2456 - val_accuracy: 0.9246
# Epoch 44/100
#
# Epoch 00044: val_accuracy improved from 0.93467 to 0.93970, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1378 - accuracy: 0.9497 - val_loss: 0.2439 - val_accuracy: 0.9397
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1342 - accuracy: 0.9421 - val_loss: 0.2448 - val_accuracy: 0.9296
# Epoch 46/100
# Epoch 00046: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1405 - accuracy: 0.9472 - val_loss: 0.2387 - val_accuracy: 0.9296
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1341 - accuracy: 0.9547 - val_loss: 0.2377 - val_accuracy: 0.9347
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1350 - accuracy: 0.9522 - val_loss: 0.2444 - val_accuracy: 0.9296
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1317 - accuracy: 0.9597 - val_loss: 0.2413 - val_accuracy: 0.9347
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1250 - accuracy: 0.9660 - val_loss: 0.2355 - val_accuracy: 0.9347
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1291 - accuracy: 0.9585 - val_loss: 0.2387 - val_accuracy: 0.9397
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1277 - accuracy: 0.9535 - val_loss: 0.2390 - val_accuracy: 0.9397
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1358 - accuracy: 0.9447 - val_loss: 0.2378 - val_accuracy: 0.9347
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1273 - accuracy: 0.9635 - val_loss: 0.2338 - val_accuracy: 0.9347
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1316 - accuracy: 0.9535 - val_loss: 0.2342 - val_accuracy: 0.9397
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1166 - accuracy: 0.9711 - val_loss: 0.2325 - val_accuracy: 0.9347
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1327 - accuracy: 0.9522 - val_loss: 0.2333 - val_accuracy: 0.9296
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1264 - accuracy: 0.9560 - val_loss: 0.2298 - val_accuracy: 0.9296
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1133 - accuracy: 0.9673 - val_loss: 0.2298 - val_accuracy: 0.9296
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1179 - accuracy: 0.9585 - val_loss: 0.2304 - val_accuracy: 0.9347
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1123 - accuracy: 0.9774 - val_loss: 0.2303 - val_accuracy: 0.9347
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1181 - accuracy: 0.9673 - val_loss: 0.2277 - val_accuracy: 0.9347
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1179 - accuracy: 0.9585 - val_loss: 0.2255 - val_accuracy: 0.9347
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1262 - accuracy: 0.9560 - val_loss: 0.2266 - val_accuracy: 0.9347
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1262 - accuracy: 0.9535 - val_loss: 0.2279 - val_accuracy: 0.9347
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1246 - accuracy: 0.9522 - val_loss: 0.2282 - val_accuracy: 0.9347
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1220 - accuracy: 0.9635 - val_loss: 0.2264 - val_accuracy: 0.9397
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1259 - accuracy: 0.9597 - val_loss: 0.2263 - val_accuracy: 0.9347
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1123 - accuracy: 0.9597 - val_loss: 0.2260 - val_accuracy: 0.9347
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1229 - accuracy: 0.9597 - val_loss: 0.2253 - val_accuracy: 0.9347
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1319 - accuracy: 0.9535 - val_loss: 0.2250 - val_accuracy: 0.9347
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1127 - accuracy: 0.9610 - val_loss: 0.2243 - val_accuracy: 0.9397
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1188 - accuracy: 0.9535 - val_loss: 0.2255 - val_accuracy: 0.9397
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1201 - accuracy: 0.9660 - val_loss: 0.2245 - val_accuracy: 0.9397
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1086 - accuracy: 0.9673 - val_loss: 0.2237 - val_accuracy: 0.9347
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1157 - accuracy: 0.9623 - val_loss: 0.2252 - val_accuracy: 0.9397
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1326 - accuracy: 0.9560 - val_loss: 0.2215 - val_accuracy: 0.9347
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1213 - accuracy: 0.9597 - val_loss: 0.2206 - val_accuracy: 0.9347
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1200 - accuracy: 0.9585 - val_loss: 0.2206 - val_accuracy: 0.9347
# Epoch 80/100
#
# Epoch 00080: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1059 - accuracy: 0.9748 - val_loss: 0.2212 - val_accuracy: 0.9347
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1099 - accuracy: 0.9660 - val_loss: 0.2206 - val_accuracy: 0.9347
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1250 - accuracy: 0.9572 - val_loss: 0.2208 - val_accuracy: 0.9397
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1154 - accuracy: 0.9673 - val_loss: 0.2208 - val_accuracy: 0.9347
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1187 - accuracy: 0.9648 - val_loss: 0.2204 - val_accuracy: 0.9347
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1155 - accuracy: 0.9585 - val_loss: 0.2190 - val_accuracy: 0.9347
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1061 - accuracy: 0.9673 - val_loss: 0.2200 - val_accuracy: 0.9347
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1223 - accuracy: 0.9635 - val_loss: 0.2204 - val_accuracy: 0.9347
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1258 - accuracy: 0.9585 - val_loss: 0.2206 - val_accuracy: 0.9347
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1061 - accuracy: 0.9673 - val_loss: 0.2207 - val_accuracy: 0.9347
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1200 - accuracy: 0.9597 - val_loss: 0.2203 - val_accuracy: 0.9347
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1050 - accuracy: 0.9698 - val_loss: 0.2203 - val_accuracy: 0.9347
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1114 - accuracy: 0.9673 - val_loss: 0.2194 - val_accuracy: 0.9347
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1170 - accuracy: 0.9648 - val_loss: 0.2199 - val_accuracy: 0.9347
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1226 - accuracy: 0.9572 - val_loss: 0.2199 - val_accuracy: 0.9347
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1148 - accuracy: 0.9660 - val_loss: 0.2200 - val_accuracy: 0.9347
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1204 - accuracy: 0.9597 - val_loss: 0.2190 - val_accuracy: 0.9347
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1152 - accuracy: 0.9635 - val_loss: 0.2207 - val_accuracy: 0.9397
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1156 - accuracy: 0.9572 - val_loss: 0.2197 - val_accuracy: 0.9397
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1199 - accuracy: 0.9610 - val_loss: 0.2192 - val_accuracy: 0.9397
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.93970
# 50/50 - 5s - loss: 0.1069 - accuracy: 0.9811 - val_loss: 0.2189 - val_accuracy: 0.9397
# accuracy: 93.97%
# ========================= 第2折结束 ============================
# ========================= 第3折开始 ============================
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.27136, saving model to model\denseNet121-weights-best.h5
# 50/50 - 7s - loss: 1.1025 - accuracy: 0.3006 - val_loss: 1.8534 - val_accuracy: 0.2714
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.27136 to 0.29146, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.8196 - accuracy: 0.3811 - val_loss: 1.6298 - val_accuracy: 0.2915
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.29146 to 0.33668, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.6559 - accuracy: 0.5094 - val_loss: 1.4950 - val_accuracy: 0.3367
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.33668 to 0.38191, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.5554 - accuracy: 0.6164 - val_loss: 1.4186 - val_accuracy: 0.3819
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.38191 to 0.39698, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.4854 - accuracy: 0.7006 - val_loss: 1.3416 - val_accuracy: 0.3970
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.39698 to 0.43216, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.4508 - accuracy: 0.7195 - val_loss: 1.2261 - val_accuracy: 0.4322
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.43216 to 0.50754, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3941 - accuracy: 0.7673 - val_loss: 1.0668 - val_accuracy: 0.5075
# Epoch 8/100
#
# Epoch 00008: val_accuracy improved from 0.50754 to 0.56784, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3520 - accuracy: 0.8050 - val_loss: 0.9248 - val_accuracy: 0.5678
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.56784 to 0.60804, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3367 - accuracy: 0.8126 - val_loss: 0.8689 - val_accuracy: 0.6080
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.60804 to 0.68342, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3152 - accuracy: 0.8440 - val_loss: 0.7620 - val_accuracy: 0.6834
# Epoch 11/100
#
# Epoch 00011: val_accuracy improved from 0.68342 to 0.76884, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2935 - accuracy: 0.8503 - val_loss: 0.6506 - val_accuracy: 0.7688
# Epoch 12/100
#
# Epoch 00012: val_accuracy improved from 0.76884 to 0.78894, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2887 - accuracy: 0.8491 - val_loss: 0.6033 - val_accuracy: 0.7889
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.78894 to 0.79397, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2483 - accuracy: 0.8881 - val_loss: 0.5684 - val_accuracy: 0.7940
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.79397 to 0.81407, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2354 - accuracy: 0.8931 - val_loss: 0.5332 - val_accuracy: 0.8141
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.81407
# 50/50 - 5s - loss: 0.2369 - accuracy: 0.8868 - val_loss: 0.4778 - val_accuracy: 0.8141
# Epoch 16/100
#
# Epoch 00016: val_accuracy improved from 0.81407 to 0.83920, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2214 - accuracy: 0.8994 - val_loss: 0.4470 - val_accuracy: 0.8392
# Epoch 17/100
#
# Epoch 00017: val_accuracy did not improve from 0.83920
# 50/50 - 5s - loss: 0.2140 - accuracy: 0.9145 - val_loss: 0.4352 - val_accuracy: 0.8392
# Epoch 18/100
#
# Epoch 00018: val_accuracy improved from 0.83920 to 0.84925, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2054 - accuracy: 0.9157 - val_loss: 0.4209 - val_accuracy: 0.8492
# Epoch 19/100
#
# Epoch 00019: val_accuracy improved from 0.84925 to 0.86935, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1988 - accuracy: 0.9208 - val_loss: 0.4018 - val_accuracy: 0.8693
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.86935
# 50/50 - 5s - loss: 0.1971 - accuracy: 0.9208 - val_loss: 0.4043 - val_accuracy: 0.8693
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.86935
# 50/50 - 5s - loss: 0.1883 - accuracy: 0.9233 - val_loss: 0.4156 - val_accuracy: 0.8643
# Epoch 22/100
#
# Epoch 00022: val_accuracy did not improve from 0.86935
# 50/50 - 5s - loss: 0.1843 - accuracy: 0.9346 - val_loss: 0.3969 - val_accuracy: 0.8643
# Epoch 23/100
#
# Epoch 00023: val_accuracy improved from 0.86935 to 0.87940, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1771 - accuracy: 0.9321 - val_loss: 0.3868 - val_accuracy: 0.8794
# Epoch 24/100
#
# Epoch 00024: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1675 - accuracy: 0.9434 - val_loss: 0.3836 - val_accuracy: 0.8693
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1700 - accuracy: 0.9346 - val_loss: 0.3879 - val_accuracy: 0.8593
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1762 - accuracy: 0.9333 - val_loss: 0.3831 - val_accuracy: 0.8643
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1787 - accuracy: 0.9182 - val_loss: 0.3730 - val_accuracy: 0.8744
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1580 - accuracy: 0.9459 - val_loss: 0.3593 - val_accuracy: 0.8744
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1626 - accuracy: 0.9434 - val_loss: 0.3807 - val_accuracy: 0.8643
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1674 - accuracy: 0.9270 - val_loss: 0.3675 - val_accuracy: 0.8693
# Epoch 31/100
#
# Epoch 00031: val_accuracy did not improve from 0.87940
# 50/50 - 5s - loss: 0.1416 - accuracy: 0.9560 - val_loss: 0.3676 - val_accuracy: 0.8744
# Epoch 32/100
#
# Epoch 00032: val_accuracy improved from 0.87940 to 0.88442, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1565 - accuracy: 0.9409 - val_loss: 0.3566 - val_accuracy: 0.8844
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1510 - accuracy: 0.9434 - val_loss: 0.3491 - val_accuracy: 0.8794
# Epoch 34/100
#
# Epoch 00034: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1499 - accuracy: 0.9484 - val_loss: 0.3528 - val_accuracy: 0.8844
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1410 - accuracy: 0.9509 - val_loss: 0.3613 - val_accuracy: 0.8693
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1523 - accuracy: 0.9472 - val_loss: 0.3520 - val_accuracy: 0.8744
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1600 - accuracy: 0.9346 - val_loss: 0.3433 - val_accuracy: 0.8744
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1408 - accuracy: 0.9635 - val_loss: 0.3350 - val_accuracy: 0.8744
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1384 - accuracy: 0.9572 - val_loss: 0.3126 - val_accuracy: 0.8844
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1241 - accuracy: 0.9673 - val_loss: 0.3234 - val_accuracy: 0.8794
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1422 - accuracy: 0.9421 - val_loss: 0.3287 - val_accuracy: 0.8844
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1404 - accuracy: 0.9447 - val_loss: 0.3323 - val_accuracy: 0.8794
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1229 - accuracy: 0.9673 - val_loss: 0.3323 - val_accuracy: 0.8844
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1322 - accuracy: 0.9472 - val_loss: 0.3281 - val_accuracy: 0.8844
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1347 - accuracy: 0.9547 - val_loss: 0.3311 - val_accuracy: 0.8794
# Epoch 46/100
#
# Epoch 00046: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1335 - accuracy: 0.9535 - val_loss: 0.3362 - val_accuracy: 0.8744
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1367 - accuracy: 0.9497 - val_loss: 0.3250 - val_accuracy: 0.8794
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.88442
# 50/50 - 5s - loss: 0.1224 - accuracy: 0.9648 - val_loss: 0.3234 - val_accuracy: 0.8794
# Epoch 49/100
#
# Epoch 00049: val_accuracy improved from 0.88442 to 0.88945, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1347 - accuracy: 0.9535 - val_loss: 0.3166 - val_accuracy: 0.8894
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.88945
# 50/50 - 5s - loss: 0.1282 - accuracy: 0.9560 - val_loss: 0.3278 - val_accuracy: 0.8844
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.88945
# 50/50 - 5s - loss: 0.1251 - accuracy: 0.9585 - val_loss: 0.3195 - val_accuracy: 0.8894
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.88945
# 50/50 - 5s - loss: 0.1168 - accuracy: 0.9623 - val_loss: 0.3206 - val_accuracy: 0.8844
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.88945
# 50/50 - 5s - loss: 0.1262 - accuracy: 0.9648 - val_loss: 0.3275 - val_accuracy: 0.8844
# Epoch 54/100
#
# Epoch 00054: val_accuracy improved from 0.88945 to 0.89447, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1277 - accuracy: 0.9585 - val_loss: 0.3171 - val_accuracy: 0.8945
# Epoch 55/100
#
# Epoch 00055: val_accuracy improved from 0.89447 to 0.89950, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1218 - accuracy: 0.9560 - val_loss: 0.3197 - val_accuracy: 0.8995
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1107 - accuracy: 0.9686 - val_loss: 0.3229 - val_accuracy: 0.8894
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1265 - accuracy: 0.9660 - val_loss: 0.3117 - val_accuracy: 0.8945
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1162 - accuracy: 0.9623 - val_loss: 0.3091 - val_accuracy: 0.8995
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1104 - accuracy: 0.9736 - val_loss: 0.3116 - val_accuracy: 0.8945
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1110 - accuracy: 0.9711 - val_loss: 0.3099 - val_accuracy: 0.8894
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1137 - accuracy: 0.9774 - val_loss: 0.3083 - val_accuracy: 0.8945
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1199 - accuracy: 0.9597 - val_loss: 0.3089 - val_accuracy: 0.8995
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1109 - accuracy: 0.9711 - val_loss: 0.3080 - val_accuracy: 0.8945
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1155 - accuracy: 0.9623 - val_loss: 0.3137 - val_accuracy: 0.8945
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1173 - accuracy: 0.9572 - val_loss: 0.3075 - val_accuracy: 0.8945
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1288 - accuracy: 0.9547 - val_loss: 0.3194 - val_accuracy: 0.8844
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1149 - accuracy: 0.9635 - val_loss: 0.3124 - val_accuracy: 0.8945
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1216 - accuracy: 0.9660 - val_loss: 0.3074 - val_accuracy: 0.8945
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1108 - accuracy: 0.9623 - val_loss: 0.3120 - val_accuracy: 0.8894
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1131 - accuracy: 0.9774 - val_loss: 0.3087 - val_accuracy: 0.8995
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1213 - accuracy: 0.9648 - val_loss: 0.3036 - val_accuracy: 0.8894
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.0997 - accuracy: 0.9786 - val_loss: 0.3020 - val_accuracy: 0.8945
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.89950
# 50/50 - 5s - loss: 0.1098 - accuracy: 0.9648 - val_loss: 0.3032 - val_accuracy: 0.8995
# Epoch 74/100
#
# Epoch 00074: val_accuracy improved from 0.89950 to 0.90452, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1157 - accuracy: 0.9547 - val_loss: 0.3093 - val_accuracy: 0.9045
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1074 - accuracy: 0.9635 - val_loss: 0.3041 - val_accuracy: 0.8995
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1137 - accuracy: 0.9673 - val_loss: 0.3026 - val_accuracy: 0.8995
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1330 - accuracy: 0.9497 - val_loss: 0.3012 - val_accuracy: 0.8945
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1225 - accuracy: 0.9535 - val_loss: 0.3025 - val_accuracy: 0.9045
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.90452
# 50/50 - 5s - loss: 0.1126 - accuracy: 0.9723 - val_loss: 0.3010 - val_accuracy: 0.8894
# Epoch 80/100
#
# Epoch 00080: val_accuracy improved from 0.90452 to 0.90955, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1038 - accuracy: 0.9698 - val_loss: 0.3014 - val_accuracy: 0.9095
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.90955
# 50/50 - 5s - loss: 0.1032 - accuracy: 0.9686 - val_loss: 0.3009 - val_accuracy: 0.8995
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.90955
# 50/50 - 5s - loss: 0.1170 - accuracy: 0.9660 - val_loss: 0.3009 - val_accuracy: 0.8995
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.90955
# 50/50 - 5s - loss: 0.1094 - accuracy: 0.9698 - val_loss: 0.2996 - val_accuracy: 0.8995
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.90955
# 50/50 - 5s - loss: 0.1119 - accuracy: 0.9660 - val_loss: 0.2991 - val_accuracy: 0.8995
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.90955
# ...
#
# Epoch 00005: val_accuracy did not improve from 0.62121
# 50/50 - 5s - loss: 0.4000 - accuracy: 0.7764 - val_loss: 0.9779 - val_accuracy: 0.6010
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.62121 to 0.63636, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3920 - accuracy: 0.7789 - val_loss: 0.9499 - val_accuracy: 0.6364
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.63636 to 0.64646, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3685 - accuracy: 0.7965 - val_loss: 0.8929 - val_accuracy: 0.6465
# Epoch 8/100
#
# Epoch 00008: val_accuracy did not improve from 0.64646
# 50/50 - 5s - loss: 0.3205 - accuracy: 0.8492 - val_loss: 0.8716 - val_accuracy: 0.6414
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.64646 to 0.67172, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.3171 - accuracy: 0.8379 - val_loss: 0.8155 - val_accuracy: 0.6717
# Epoch 10/100
#
# Epoch 00010: val_accuracy did not improve from 0.67172
# 50/50 - 5s - loss: 0.2981 - accuracy: 0.8480 - val_loss: 0.7246 - val_accuracy: 0.6717
# Epoch 11/100
#
# Epoch 00011: val_accuracy improved from 0.67172 to 0.67677, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2804 - accuracy: 0.8719 - val_loss: 0.7581 - val_accuracy: 0.6768
# Epoch 12/100
#
# Epoch 00012: val_accuracy improved from 0.67677 to 0.70202, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2526 - accuracy: 0.8882 - val_loss: 0.6824 - val_accuracy: 0.7020
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.70202 to 0.76263, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2454 - accuracy: 0.8869 - val_loss: 0.5669 - val_accuracy: 0.7626
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.76263 to 0.77273, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2511 - accuracy: 0.8731 - val_loss: 0.5760 - val_accuracy: 0.7727
# Epoch 15/100
#
# Epoch 00015: val_accuracy improved from 0.77273 to 0.81818, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2225 - accuracy: 0.8957 - val_loss: 0.4683 - val_accuracy: 0.8182
# Epoch 16/100
#
# Epoch 00016: val_accuracy did not improve from 0.81818
# 50/50 - 5s - loss: 0.2059 - accuracy: 0.9133 - val_loss: 0.5588 - val_accuracy: 0.7828
# Epoch 17/100
#
# Epoch 00017: val_accuracy improved from 0.81818 to 0.83333, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.2119 - accuracy: 0.9108 - val_loss: 0.4667 - val_accuracy: 0.8333
# Epoch 18/100
#
# Epoch 00018: val_accuracy improved from 0.83333 to 0.84848, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1978 - accuracy: 0.9121 - val_loss: 0.4183 - val_accuracy: 0.8485
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.84848
# 50/50 - 5s - loss: 0.1890 - accuracy: 0.9296 - val_loss: 0.4192 - val_accuracy: 0.8384
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.84848
# 50/50 - 5s - loss: 0.1871 - accuracy: 0.9259 - val_loss: 0.4024 - val_accuracy: 0.8485
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.84848
# 50/50 - 5s - loss: 0.1816 - accuracy: 0.9359 - val_loss: 0.4098 - val_accuracy: 0.8283
# Epoch 22/100
#
# Epoch 00022: val_accuracy improved from 0.84848 to 0.85354, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1749 - accuracy: 0.9384 - val_loss: 0.3990 - val_accuracy: 0.8535
# Epoch 23/100
#
# Epoch 00023: val_accuracy did not improve from 0.85354
# 50/50 - 5s - loss: 0.1674 - accuracy: 0.9359 - val_loss: 0.4032 - val_accuracy: 0.8434
# Epoch 24/100
#
# Epoch 00024: val_accuracy improved from 0.85354 to 0.86364, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1614 - accuracy: 0.9359 - val_loss: 0.3877 - val_accuracy: 0.8636
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.86364
# 50/50 - 5s - loss: 0.1584 - accuracy: 0.9510 - val_loss: 0.3773 - val_accuracy: 0.8636
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.86364
# 50/50 - 5s - loss: 0.1557 - accuracy: 0.9410 - val_loss: 0.3889 - val_accuracy: 0.8485
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.86364
# 50/50 - 5s - loss: 0.1615 - accuracy: 0.9359 - val_loss: 0.3799 - val_accuracy: 0.8636
# Epoch 28/100
#
# Epoch 00028: val_accuracy improved from 0.86364 to 0.87374, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1535 - accuracy: 0.9497 - val_loss: 0.3644 - val_accuracy: 0.8737
# Epoch 29/100
#
# Epoch 00029: val_accuracy improved from 0.87374 to 0.87879, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1505 - accuracy: 0.9460 - val_loss: 0.3671 - val_accuracy: 0.8788
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1573 - accuracy: 0.9497 - val_loss: 0.3613 - val_accuracy: 0.8636
# Epoch 31/100
#
# Epoch 00031: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1526 - accuracy: 0.9510 - val_loss: 0.3775 - val_accuracy: 0.8485
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1516 - accuracy: 0.9435 - val_loss: 0.3805 - val_accuracy: 0.8434
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1526 - accuracy: 0.9460 - val_loss: 0.3486 - val_accuracy: 0.8737
# Epoch 34/100
#
# Epoch 00034: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1396 - accuracy: 0.9510 - val_loss: 0.3375 - val_accuracy: 0.8687
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1392 - accuracy: 0.9573 - val_loss: 0.3600 - val_accuracy: 0.8535
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1318 - accuracy: 0.9623 - val_loss: 0.3634 - val_accuracy: 0.8485
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1364 - accuracy: 0.9560 - val_loss: 0.3520 - val_accuracy: 0.8434
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.87879
# 50/50 - 5s - loss: 0.1323 - accuracy: 0.9585 - val_loss: 0.3571 - val_accuracy: 0.8636
# Epoch 39/100
#
# Epoch 00039: val_accuracy improved from 0.87879 to 0.88889, saving model to model\denseNet121-weights-best.h5
# 50/50 - 6s - loss: 0.1448 - accuracy: 0.9384 - val_loss: 0.3405 - val_accuracy: 0.8889
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1300 - accuracy: 0.9573 - val_loss: 0.3335 - val_accuracy: 0.8788
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1316 - accuracy: 0.9573 - val_loss: 0.3401 - val_accuracy: 0.8687
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1419 - accuracy: 0.9560 - val_loss: 0.3174 - val_accuracy: 0.8687
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1277 - accuracy: 0.9560 - val_loss: 0.3256 - val_accuracy: 0.8838
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1237 - accuracy: 0.9585 - val_loss: 0.3369 - val_accuracy: 0.8737
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1257 - accuracy: 0.9673 - val_loss: 0.3339 - val_accuracy: 0.8788
# Epoch 46/100
#
# Epoch 00046: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1373 - accuracy: 0.9573 - val_loss: 0.3308 - val_accuracy: 0.8737
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1200 - accuracy: 0.9736 - val_loss: 0.3181 - val_accuracy: 0.8737
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1216 - accuracy: 0.9636 - val_loss: 0.3344 - val_accuracy: 0.8636
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1202 - accuracy: 0.9585 - val_loss: 0.3480 - val_accuracy: 0.8737
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1195 - accuracy: 0.9623 - val_loss: 0.3166 - val_accuracy: 0.8788
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1295 - accuracy: 0.9673 - val_loss: 0.3240 - val_accuracy: 0.8788
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1204 - accuracy: 0.9573 - val_loss: 0.3203 - val_accuracy: 0.8687
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1327 - accuracy: 0.9548 - val_loss: 0.3241 - val_accuracy: 0.8636
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1205 - accuracy: 0.9661 - val_loss: 0.3122 - val_accuracy: 0.8889
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1197 - accuracy: 0.9585 - val_loss: 0.3163 - val_accuracy: 0.8788
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1271 - accuracy: 0.9573 - val_loss: 0.3177 - val_accuracy: 0.8788
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1258 - accuracy: 0.9623 - val_loss: 0.3153 - val_accuracy: 0.8788
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1133 - accuracy: 0.9711 - val_loss: 0.3200 - val_accuracy: 0.8737
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1163 - accuracy: 0.9648 - val_loss: 0.3139 - val_accuracy: 0.8838
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1088 - accuracy: 0.9661 - val_loss: 0.3132 - val_accuracy: 0.8687
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1139 - accuracy: 0.9623 - val_loss: 0.3113 - val_accuracy: 0.8687
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1223 - accuracy: 0.9560 - val_loss: 0.3132 - val_accuracy: 0.8737
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1138 - accuracy: 0.9698 - val_loss: 0.3177 - val_accuracy: 0.8737
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1122 - accuracy: 0.9686 - val_loss: 0.3144 - val_accuracy: 0.8687
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1192 - accuracy: 0.9623 - val_loss: 0.3130 - val_accuracy: 0.8687
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1086 - accuracy: 0.9661 - val_loss: 0.3114 - val_accuracy: 0.8737
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1185 - accuracy: 0.9573 - val_loss: 0.3041 - val_accuracy: 0.8788
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1042 - accuracy: 0.9736 - val_loss: 0.3073 - val_accuracy: 0.8687
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1145 - accuracy: 0.9611 - val_loss: 0.3014 - val_accuracy: 0.8838
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1176 - accuracy: 0.9573 - val_loss: 0.3058 - val_accuracy: 0.8687
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1272 - accuracy: 0.9598 - val_loss: 0.3055 - val_accuracy: 0.8838
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1182 - accuracy: 0.9623 - val_loss: 0.3039 - val_accuracy: 0.8788
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1055 - accuracy: 0.9698 - val_loss: 0.2996 - val_accuracy: 0.8838
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1139 - accuracy: 0.9636 - val_loss: 0.2963 - val_accuracy: 0.8788
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1068 - accuracy: 0.9711 - val_loss: 0.2990 - val_accuracy: 0.8788
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1088 - accuracy: 0.9724 - val_loss: 0.3072 - val_accuracy: 0.8737
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1066 - accuracy: 0.9585 - val_loss: 0.3029 - val_accuracy: 0.8788
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1146 - accuracy: 0.9611 - val_loss: 0.3047 - val_accuracy: 0.8788
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1086 - accuracy: 0.9711 - val_loss: 0.3075 - val_accuracy: 0.8737
# Epoch 80/100
#
# Epoch 00080: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1101 - accuracy: 0.9698 - val_loss: 0.3017 - val_accuracy: 0.8788
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1098 - accuracy: 0.9661 - val_loss: 0.3040 - val_accuracy: 0.8788
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1176 - accuracy: 0.9573 - val_loss: 0.3004 - val_accuracy: 0.8737
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1051 - accuracy: 0.9661 - val_loss: 0.2993 - val_accuracy: 0.8737
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1046 - accuracy: 0.9711 - val_loss: 0.3004 - val_accuracy: 0.8788
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1260 - accuracy: 0.9510 - val_loss: 0.3001 - val_accuracy: 0.8788
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1061 - accuracy: 0.9812 - val_loss: 0.3015 - val_accuracy: 0.8788
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1050 - accuracy: 0.9673 - val_loss: 0.3010 - val_accuracy: 0.8737
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1138 - accuracy: 0.9686 - val_loss: 0.3011 - val_accuracy: 0.8687
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1100 - accuracy: 0.9724 - val_loss: 0.3015 - val_accuracy: 0.8737
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1031 - accuracy: 0.9724 - val_loss: 0.3002 - val_accuracy: 0.8788
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1094 - accuracy: 0.9661 - val_loss: 0.3016 - val_accuracy: 0.8737
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1033 - accuracy: 0.9686 - val_loss: 0.3014 - val_accuracy: 0.8737
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1109 - accuracy: 0.9573 - val_loss: 0.2987 - val_accuracy: 0.8788
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1018 - accuracy: 0.9648 - val_loss: 0.2950 - val_accuracy: 0.8788
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1076 - accuracy: 0.9724 - val_loss: 0.2959 - val_accuracy: 0.8889
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1092 - accuracy: 0.9661 - val_loss: 0.2985 - val_accuracy: 0.8788
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.0997 - accuracy: 0.9673 - val_loss: 0.2973 - val_accuracy: 0.8788
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1051 - accuracy: 0.9611 - val_loss: 0.2941 - val_accuracy: 0.8889
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1159 - accuracy: 0.9661 - val_loss: 0.2935 - val_accuracy: 0.8838
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.88889
# 50/50 - 5s - loss: 0.1052 - accuracy: 0.9686 - val_loss: 0.2947 - val_accuracy: 0.8838
# accuracy: 88.89%
# ========================= 第5折结束 ============================
# accuracy：91.95% (+/- 2.05%)
# precision：92.30% (+/- 2.11%)
# recall：92.09% (+/- 1.97%)
# f1-score：92.13% (+/- 2.02%)
# auc：98.03% (+/- 0.84%)

# %%
X = np.load("newData/image.npy")
Y = np.load("newData/label.npy")

# %%
predict = model.predict([X])

y = label_binarize(Y, classes=[0, 1, 2])
n_classes = y.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y[:, i], predict[:, i], )
    roc_auc[i] = auc(fpr[i], tpr[i])
roc_auc["macro"] = roc_auc_score(y, predict, multi_class="ovo", average="macro")
roc_auc["weighted"] = roc_auc_score(y, predict, multi_class="ovo", average="weighted")


y_pre = np.argmax(predict, axis=1)
report = classification_report(Y, y_pre, output_dict=True)
df1 = pd.DataFrame(report).transpose()
df1['auc'] = [roc_auc[0], roc_auc[1], roc_auc[2], '', roc_auc["macro"], roc_auc["weighted"]]
df1
# Out:
#               precision    recall  f1-score      support       auc
# 0              0.889211  0.915735  0.902278  1341.000000  0.978168
# 1              0.871138  0.859480  0.865269  1345.000000  0.960135
# 2              0.932937  0.915833  0.924306  1200.000000  0.989029
# accuracy       0.896294  0.896294  0.896294     0.896294
# macro avg      0.897762  0.897016  0.897284  3886.000000  0.975778
# weighted avg   0.896458  0.896294  0.896271  3886.000000  0.975281
